# %% [markdown]
# ### Registration

# %% [markdown]
# **Learning outcomes:**
# - How to apply registration to an image using ants.

# %%
# %matplotlib inline

import os
from helpers import *

import ants
# noinspection PyPep8Naming
import SimpleITK as sitk

print(f'AntsPy version = {ants.__version__}')
print(f'SimpleITK version = {sitk.__version__}')
# Out:
# AntsPy version = 0.5.4
# SimpleITK version = 2.4.1

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
print(f'project folder = {BASE_DIR}')
# Out:
# project folder = /home/younes/PycharmProjects/MRI-preprocessing-techniques

# %%
raw_examples = [
    'fsl-open-dev_sub-001_T1w.nii.gz',
    'wash-120_sub-001_T1w.nii.gz',
    'kf-panda_sub-01_ses-3T_T1w.nii.gz',
    'listen-task_sub-UTS01_ses-1_T1w.nii.gz'
]

# %% [markdown]
# #### Raw image

# %%
raw_example = raw_examples[0]
raw_img_path = os.path.join(BASE_DIR, 'assets', 'raw_examples', raw_example)
raw_img_ants = ants.image_read(raw_img_path, reorient='IAL')

explore_3D_array(arr=raw_img_ants.numpy())
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# #### Template image

# %%
template_img_path = os.path.join(BASE_DIR, 'assets', 'templates', 'mni_icbm152_t1_tal_nlin_sym_09a.nii')
template_img_ants = ants.image_read(template_img_path, reorient='IAL')

explore_3D_array(arr = template_img_ants.numpy())
# Out:
# interactive(children=(IntSlider(value=94, description='SLICE', max=188), Output()), _dom_classes=('widget-inte…

# %%
print('\t\tRAW IMG')
print(raw_img_ants)

print('\t\tTEMPLATE IMG')
print(template_img_ants)
# Out:
# 		RAW IMG
# ANTsImage (IAL)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (192, 192, 160)
# 	 Spacing    : (1.25, 1.25, 1.2)
# 	 Origin     : (98.1114, -149.1525, -129.5975)
# 	 Direction  : [ 0.  0. -1.  0.  1.  0.  1.  0.  0.]
#
# 		TEMPLATE IMG
# ANTsImage (IAL)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (189, 233, 197)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (98.0, -98.0, -72.0)
# 	 Direction  : [ 0.  0. -1.  0.  1.  0.  1.  0.  0.]

# %% [markdown]
# #### Registration

# %%
transformation = ants.registration(
    fixed=template_img_ants,
    moving=raw_img_ants, 
    type_of_transform='SyN',
    verbose=True
)
# Out:
# antsRegistration -d 3 -r [0x7e6fdf89b3e8,0x7e6fdf89a1a8,1] -m mattes[0x7e6fdf89b3e8,0x7e6fdf89a1a8,1,32,regular,0.2] -t Affine[0.25] -c 2100x1200x1200x0 -s 3x2x1x0 -f 4x2x2x1 -x [NA,NA] -m mattes[0x7e6fdf89b3e8,0x7e6fdf89a1a8,1,32] -t SyN[0.200000,3.000000,0.000000] -c [40x20x0,1e-7,8] -s 2x1x0 -f 4x2x1 -u 1 -z 1 -o [/tmp/tmpthqnunex,0x7e6fdf89abc8,0x7e6fdf89afe8] -x [NA,NA] --float 1 --write-composite-transform 0 -v 1
# All_Command_lines_OK
# Using single precision for computations.
# =============================================================================
# The composite transform comprises the following transforms (in order):
#   1. Center of mass alignment using fixed image: 0x7e6fdf89b3e8 and moving image: 0x7e6fdf89a1a8 (type = Euler3DTransform)
# =============================================================================
#   Reading mask(s).
#     Registration stage 0
#       No fixed mask
#       No moving mask
#     Registration stage 1
#       No fixed mask
#       No moving mask
#   number of levels = 4
#   number of levels = 3
#   fixed image: 0x7e6fdf89b3e8
#   moving image: 0x7e6fdf89a1a8
#   fixed image: 0x7e6fdf89b3e8
#   moving image: 0x7e6fdf89a1a8
# Dimension = 3
# Number of stages = 2
# Use histogram matching = true
# Winsorize image intensities = false
#   Lower quantile = 0
#   Upper quantile = 1
#
#
# Stage 1 State
#    Image metric = MattesMI
#      Fixed image = Image (0x36160fe0)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2296
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2268
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   Spacing: [1, 1, 1]
#   Origin: [98, -98, -72]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   PointToIndexMatrix:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x362d84e0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2266
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x7e6fb3c00010
#       Container manages memory: true
#       Size: 8675289
#       Capacity: 8675289
#
#      Moving image = Image (0x3628c390)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2297
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2294
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   Spacing: [1.25, 1.25, 1.2]
#   Origin: [98.1114, -149.153, -129.597]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1.2
# 0 1.25 0
# 1.25 0 0
#
#   PointToIndexMatrix:
# 0 0 0.8
# 0 0.8 0
# -0.833333 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x362d1b40)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2292
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x3bf80540
#       Container manages memory: true
#       Size: 5898240
#       Capacity: 5898240
#
#      Weighting = 1
#      Sampling strategy = regular
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 0.2
#    Transform = Affine
#      Gradient step = 0.25
#      Update field sigma (voxel space) = 0
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Stage 2 State
#    Image metric = MattesMI
#      Fixed image = Image (0x3628d350)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2348
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2320
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   Spacing: [1, 1, 1]
#   Origin: [98, -98, -72]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   PointToIndexMatrix:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x361936b0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2318
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x7e6fb1a00010
#       Container manages memory: true
#       Size: 8675289
#       Capacity: 8675289
#
#      Moving image = Image (0x3628d5e0)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2349
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2346
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   Spacing: [1.25, 1.25, 1.2]
#   Origin: [98.1114, -149.153, -129.597]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1.2
# 0 1.25 0
# 1.25 0 0
#
#   PointToIndexMatrix:
# 0 0 0.8
# 0 0.8 0
# -0.833333 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x39160630)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2344
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x3d600550
#       Container manages memory: true
#       Size: 5898240
#       Capacity: 5898240
#
#      Weighting = 1
#      Sampling strategy = none
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 1
#    Transform = SyN
#      Gradient step = 0.2
#      Update field sigma (voxel space) = 3
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Registration using 2 total stages.
#
# Stage 0
#   iterations = 2100x1200x1200x0
#   convergence threshold = 1e-06
#   convergence window size = 10
#   number of levels = 4
#   using the Mattes MI metric (number of bins = 32, weight = 1, use gradient filter = 0)
#   preprocessing:  histogram matching the images
#   Shrink factors (level 1 out of 4): [4, 4, 4]
#   Shrink factors (level 2 out of 4): [2, 2, 2]
#   Shrink factors (level 3 out of 4): [2, 2, 2]
#   Shrink factors (level 4 out of 4): [1, 1, 1]
#   smoothing sigmas per level: [3, 2, 1, 0]
#   regular sampling (percentage = 0.2)
#
# *** Running AffineTransform registration ***
#
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -4.969224333763e-01, inf, 4.9864e-01, 4.9864e-01,
#  2DIAGNOSTIC,     2, -5.002541542053e-01, inf, 5.2744e-01, 2.8797e-02,
#  2DIAGNOSTIC,     3, -5.059552192688e-01, inf, 5.5538e-01, 2.7940e-02,
#  2DIAGNOSTIC,     4, -5.152071714401e-01, inf, 5.8484e-01, 2.9461e-02,
#  2DIAGNOSTIC,    10, -8.159309029579e-01, 3.831095091300e-05, 1.3063e+01, 2.1191e-01,
#  2DIAGNOSTIC,    11, -8.159313797951e-01, 1.342381619907e-05, 1.3268e+01, 2.0416e-01,
#  2DIAGNOSTIC,    12, -8.159319758415e-01, 5.573595899477e-06, 1.3477e+01, 2.0992e-01,
#  2DIAGNOSTIC,    13, -8.159310817719e-01, 3.005297685377e-06, 1.3681e+01, 2.0371e-01,
#  2DIAGNOSTIC,    14, -8.159315586090e-01, 2.337686282772e-06, 1.3888e+01, 2.0670e-01,
#  2DIAGNOSTIC,    15, -8.159314990044e-01, 2.164983925468e-06, 1.4147e+01, 2.5876e-01,
#  2DIAGNOSTIC,    16, -8.159316182137e-01, 2.023464503509e-06, 1.4353e+01, 2.0669e-01,
#  2DIAGNOSTIC,    17, -8.159314393997e-01, 1.900238203234e-06, 1.4582e+01, 2.2846e-01,
#  2DIAGNOSTIC,    18, -8.159315586090e-01, 1.787257588148e-06, 1.4844e+01, 2.6197e-01,
#  2DIAGNOSTIC,    19, -8.159315586090e-01, 1.686709538262e-06, 1.5055e+01, 2.1174e-01,
#  2DIAGNOSTIC,    20, -8.159316778183e-01, 1.594651507730e-06, 1.5259e+01, 2.0338e-01,
#  2DIAGNOSTIC,    21, -8.159317374229e-01, 1.519506440673e-06, 1.5468e+01, 2.0881e-01,
#  2DIAGNOSTIC,    22, -8.159314393997e-01, 1.455988922316e-06, 1.5672e+01, 2.0479e-01,
#  2DIAGNOSTIC,    23, -8.159316778183e-01, 1.387089810123e-06, 1.5887e+01, 2.1474e-01,
#  2DIAGNOSTIC,    24, -8.159316182137e-01, 1.329469910161e-06, 1.6120e+01, 2.3292e-01,
#  2DIAGNOSTIC,    25, -8.159316182137e-01, 1.275169552173e-06, 1.6323e+01, 2.0273e-01,
#  2DIAGNOSTIC,    26, -8.159318566322e-01, 1.229709255313e-06, 1.6556e+01, 2.3304e-01,
#  2DIAGNOSTIC,    27, -8.159319758415e-01, 1.186195390801e-06, 1.6762e+01, 2.0594e-01,
#  2DIAGNOSTIC,    28, -8.159317970276e-01, 1.144284624388e-06, 1.6974e+01, 2.1169e-01,
#  2DIAGNOSTIC,    29, -8.159317374229e-01, 1.103813474401e-06, 1.7185e+01, 2.1164e-01,
#  2DIAGNOSTIC,    30, -8.159315586090e-01, 1.064692014552e-06, 1.7391e+01, 2.0569e-01,
#  2DIAGNOSTIC,    31, -8.159316182137e-01, 1.029109739648e-06, 1.7616e+01, 2.2500e-01,
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -6.837645769119e-01, inf, 1.9683e+01, 2.0673e+00,
#   Elapsed time (stage 0): 2.0655e+01
#
#
# Stage 1
#   iterations = 40x20x0
#   convergence threshold = 1.0000e-07
#   convergence window size = 8
#   number of levels = 3
#   using the Mattes MI metric (number of bins = 32, weight = 1.0000e+00, use gradient filter = 0)
#   preprocessing:  histogram matching the images
#   Shrink factors (level 1 out of 3): [4, 4, 4]
#   Shrink factors (level 2 out of 3): [2, 2, 2]
#   Shrink factors (level 3 out of 3): [1, 1, 1]
#   smoothing sigmas per level: [2, 1, 0]
#   Using default NONE metricSamplingStrategy
#
# *** Running SyN registration (varianceForUpdateField = 3.0000e+00, varianceForTotalField = 0.0000e+00) ***
#
# XXDIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#
#  1DIAGNOSTIC,    11, -1.046021938324e+00, 2.243198687211e-03, 3.0075e+01, 1.6860e+00,
#  1DIAGNOSTIC,    12, -1.049398660660e+00, 1.884822617285e-03, 3.1826e+01, 1.7511e+00,
#  1DIAGNOSTIC,    13, -1.052561283112e+00, 1.586901256815e-03, 3.3633e+01, 1.8065e+00,
#  1DIAGNOSTIC,    14, -1.055363893509e+00, 1.324224984273e-03, 3.5379e+01, 1.7465e+00,
#  1DIAGNOSTIC,    15, -1.057459115982e+00, 1.086038537323e-03, 3.7128e+01, 1.7485e+00,
#  1DIAGNOSTIC,    16, -1.058859944344e+00, 8.725673542358e-04, 3.8864e+01, 1.7367e+00,
#  1DIAGNOSTIC,    17, -1.060864806175e+00, 7.015309529379e-04, 4.0601e+01, 1.7366e+00,
#  1DIAGNOSTIC,    18, -1.062025308609e+00, 5.593129317276e-04, 4.2337e+01, 1.7364e+00,
#  1DIAGNOSTIC,    19, -1.063795566559e+00, 4.600480315275e-04, 4.4014e+01, 1.6767e+00,
#  1DIAGNOSTIC,    20, -1.064804553986e+00, 3.786169982050e-04, 4.5820e+01, 1.8066e+00,
#   Elapsed time (stage 1): 49.01
#
#
# Total elapsed time: 69.68

# %%
print(transformation)
# Out:
# {'warpedmovout': ANTsImage (IAL)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (189, 233, 197)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (98.0, -98.0, -72.0)
# 	 Direction  : [ 0.  0. -1.  0.  1.  0.  1.  0.  0.]
# , 'warpedfixout': ANTsImage (IAL)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (192, 192, 160)
# 	 Spacing    : (1.25, 1.25, 1.2)
# 	 Origin     : (98.1114, -149.1525, -129.5975)
# 	 Direction  : [ 0.  0. -1.  0.  1.  0.  1.  0.  0.]
# , 'fwdtransforms': ['/tmp/tmpthqnunex1Warp.nii.gz', '/tmp/tmpthqnunex0GenericAffine.mat'], 'invtransforms': ['/tmp/tmpthqnunex0GenericAffine.mat', '/tmp/tmpthqnunex1InverseWarp.nii.gz']}

# %%
registered_img_ants = transformation['warpedmovout']

explore_3D_array(arr=registered_img_ants.numpy())
# Out:
# interactive(children=(IntSlider(value=94, description='SLICE', max=188), Output()), _dom_classes=('widget-inte…

# %%
out_folder =  os.path.join(BASE_DIR, 'assets', 'preprocessed')
out_folder = os.path.join(out_folder, raw_example.split('.')[0]) # create folder with name of the raw file
os.makedirs(out_folder, exist_ok=True) # create folder if not exists

out_filename = add_suffix_to_filename(raw_example, suffix='registered')
out_path = os.path.join(out_folder, out_filename)

print(raw_img_path[len(BASE_DIR):])
print(out_path[len(BASE_DIR):])
# Out:
# /assets/raw_examples/fsl-open-dev_sub-001_T1w.nii.gz
# /assets/preprocessed/fsl-open-dev_sub-001_T1w/fsl-open-dev_sub-001_T1w_registered.nii.gz

# %%
registered_img_ants.to_file(out_path)
