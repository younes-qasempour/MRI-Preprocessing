# %% [markdown]
# ### Brain extraction(Skull stripping)

# %% [markdown]
# **Learning outcomes:**
# - How to do brain extraction using registration.

# %%
# %matplotlib inline

import os
from helpers import *

import ants
# noinspection PyPep8Naming
import SimpleITK as sitk

print(f'AntsPy version = {ants.__version__}')
print(f'SimpleITK version = {sitk.__version__}')
# Out:
# AntsPy version = 0.5.4
# SimpleITK version = 2.4.1

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
print(f'project folder = {BASE_DIR}')
# Out:
# project folder = /home/younes/PycharmProjects/MRI-preprocessing-techniques

# %%
raw_examples = [
    'fsl-open-dev_sub-001_T1w.nii.gz',
    'wash-120_sub-001_T1w.nii.gz',
    'kf-panda_sub-01_ses-3T_T1w.nii.gz',
    'listen-task_sub-UTS01_ses-1_T1w.nii.gz',
]

# %% [markdown]
# #### Raw Image

# %%
raw_example = raw_examples[0]
raw_img_path = os.path.join(BASE_DIR, 'assets', 'raw_examples', raw_example)
raw_img_ants = ants.image_read(raw_img_path, reorient='IAL')

explore_3D_array(arr=raw_img_ants.numpy(), cmap='nipy_spectral')
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ### Template based method (Native space)

# %% [markdown]
# #### Template Image

# %%
template_img_path = os.path.join(BASE_DIR, 'assets', 'templates', 'mni_icbm152_t1_tal_nlin_sym_09a.nii')
template_img_ants = ants.image_read(template_img_path, reorient='IAL')

explore_3D_array(arr = template_img_ants.numpy())
# Out:
# interactive(children=(IntSlider(value=94, description='SLICE', max=188), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# #### Brain Mask of the template

# %%
mask_template_img_path = os.path.join(BASE_DIR, 'assets', 'templates', 'mni_icbm152_t1_tal_nlin_sym_09a_mask.nii')
mask_template_img_ants = ants.image_read(mask_template_img_path, reorient='IAL')

explore_3D_array(mask_template_img_ants.numpy())
# Out:
# interactive(children=(IntSlider(value=94, description='SLICE', max=188), Output()), _dom_classes=('widget-inte…

# %%
np.unique(mask_template_img_ants.numpy())
# Out:
# array([0., 1.], dtype=float32)

# %% [markdown]
# #### Register template to raw image

# %%
transformation = ants.registration(
    fixed=raw_img_ants,
    moving=template_img_ants, 
    type_of_transform='SyN',
    verbose=True
)
# Out:
# antsRegistration -d 3 -r [0x78aadc525b08,0x78aadc525a48,1] -m mattes[0x78aadc525b08,0x78aadc525a48,1,32,regular,0.2] -t Affine[0.25] -c 2100x1200x1200x0 -s 3x2x1x0 -f 4x2x2x1 -x [NA,NA] -m mattes[0x78aadc525b08,0x78aadc525a48,1,32] -t SyN[0.200000,3.000000,0.000000] -c [40x20x0,1e-7,8] -s 2x1x0 -f 4x2x1 -u 1 -z 1 -o [/tmp/tmp4a8bhk53,0x78aadc5268e8,0x78aadc526728] -x [NA,NA] --float 1 --write-composite-transform 0 -v 1
# All_Command_lines_OK
# Using single precision for computations.
# =============================================================================
# The composite transform comprises the following transforms (in order):
#   1. Center of mass alignment using fixed image: 0x78aadc525b08 and moving image: 0x78aadc525a48 (type = Euler3DTransform)
# =============================================================================
#   Reading mask(s).
#     Registration stage 0
#       No fixed mask
#       No moving mask
#     Registration stage 1
#       No fixed mask
#       No moving mask
#   number of levels = 4
#   number of levels = 3
#   fixed image: 0x78aadc525b08
#   moving image: 0x78aadc525a48
#   fixed image: 0x78aadc525b08
#   moving image: 0x78aadc525a48
# Dimension = 3
# Number of stages = 2
# Use histogram matching = true
# Winsorize image intensities = false
#   Lower quantile = 0
#   Upper quantile = 1
#
#
# Stage 1 State
#    Image metric = MattesMI
#      Fixed image = Image (0x3f992950)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2940
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2914
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   Spacing: [1.25, 1.25, 1.2]
#   Origin: [98.1114, -149.153, -129.597]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1.2
# 0 1.25 0
# 1.25 0 0
#
#   PointToIndexMatrix:
# 0 0 0.8
# 0 0.8 0
# -0.833333 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x3fb75030)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2912
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x457b9f50
#       Container manages memory: true
#       Size: 5898240
#       Capacity: 5898240
#
#      Moving image = Image (0x3fb0e040)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2941
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2938
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   Spacing: [1, 1, 1]
#   Origin: [98, -98, -72]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   PointToIndexMatrix:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x3fb722c0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2936
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x78aaa9600010
#       Container manages memory: true
#       Size: 8675289
#       Capacity: 8675289
#
#      Weighting = 1
#      Sampling strategy = regular
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 0.2
#    Transform = Affine
#      Gradient step = 0.25
#      Update field sigma (voxel space) = 0
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Stage 2 State
#    Image metric = MattesMI
#      Fixed image = Image (0x3fb0ebe0)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2992
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2966
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [192, 192, 160]
#   Spacing: [1.25, 1.25, 1.2]
#   Origin: [98.1114, -149.153, -129.597]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1.2
# 0 1.25 0
# 1.25 0 0
#
#   PointToIndexMatrix:
# 0 0 0.8
# 0 0.8 0
# -0.833333 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x4299b320)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2964
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x46e39f60
#       Container manages memory: true
#       Size: 5898240
#       Capacity: 5898240
#
#      Moving image = Image (0x3fb0ee70)
#   RTTI typeinfo:   itk::Image<float, 3u>
#   Reference Count: 2
#   Modified Time: 2993
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 0
#   UpdateMTime: 2990
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [189, 233, 197]
#   Spacing: [1, 1, 1]
#   Origin: [98, -98, -72]
#   Direction:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   IndexToPointMatrix:
# 0 0 -1
# 0 1 0
# 1 0 0
#
#   PointToIndexMatrix:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   Inverse Direction:
# 0 0 1
# 0 1 0
# -1 0 0
#
#   PixelContainer:
#     ImportImageContainer (0x3fa8aa20)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, float>
#       Reference Count: 1
#       Modified Time: 2988
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x78aaa7400010
#       Container manages memory: true
#       Size: 8675289
#       Capacity: 8675289
#
#      Weighting = 1
#      Sampling strategy = none
#      Number of bins = 32
#      Radius = 4
#      Sampling percentage  = 1
#    Transform = SyN
#      Gradient step = 0.2
#      Update field sigma (voxel space) = 3
#      Total field sigma (voxel space) = 0
#      Update field time sigma = 0
#      Total field time sigma  = 0
#      Number of time indices = 0
#      Number of time point samples = 0
# Registration using 2 total stages.
#
# Stage 0
#   iterations = 2100x1200x1200x0
#   convergence threshold = 1e-06
#   convergence window size = 10
#   number of levels = 4
#   using the Mattes MI metric (number of bins = 32, weight = 1, use gradient filter = 0)
#   preprocessing:  histogram matching the images
#   Shrink factors (level 1 out of 4): [4, 4, 4]
#   Shrink factors (level 2 out of 4): [2, 2, 2]
#   Shrink factors (level 3 out of 4): [2, 2, 2]
#   Shrink factors (level 4 out of 4): [1, 1, 1]
#   smoothing sigmas per level: [3, 2, 1, 0]
#   regular sampling (percentage = 0.2)
#
# *** Running AffineTransform registration ***
#
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -4.672305881977e-01, inf, 5.8875e-01, 5.8875e-01,
#  2DIAGNOSTIC,     2, -4.701269268990e-01, inf, 6.2497e-01, 3.6220e-02,
#  2DIAGNOSTIC,     3, -4.750248789787e-01, inf, 6.5671e-01, 3.1732e-02,
#  2DIAGNOSTIC,     4, -4.831405580044e-01, inf, 6.8132e-01, 2.4617e-02,
#  2DIAGNOSTIC,     5, -4.957837462425e-01, inf, 7.0689e-01, 2.5563e-02,
#  2DIAGNOSTIC,     6, -5.145476460457e-01, inf, 7.3372e-01, 2.6837e-02,
#  2DIAGNOSTIC,     7, -5.395449995995e-01, inf, 7.5883e-01, 2.5107e-02,
#  2DIAGNOSTIC,     8, -5.685773491859e-01, inf, 7.8822e-01, 2.9392e-02,
#  2DIAGNOSTIC,     9, -5.750361084938e-01, inf, 8.1730e-01, 2.9075e-02,
#  2DIAGNOSTIC,    10, -5.754306316376e-01, 1.623590476811e-02, 8.4233e-01, 2.5033e-02,
#  2DIAGNOSTIC,    11, -5.763443708420e-01, 1.468514557928e-02, 8.6890e-01, 2.6570e-02,
#  2DIAGNOSTIC,    12, -5.766534209251e-01, 1.223994418979e-02, 8.9146e-01, 2.2561e-02,
#  2DIAGNOSTIC,    13, -5.767015814781e-01, 9.295386262238e-03, 9.2058e-01, 2.9119e-02,
#  2DIAGNOSTIC,    14, -5.769705772400e-01, 6.288001313806e-03, 9.5369e-01, 3.3113e-02,
#  2DIAGNOSTIC,    15, -5.768650174141e-01, 3.590949811041e-03, 9.8450e-01, 3.0807e-02,
#  2DIAGNOSTIC,    16, -5.766360163689e-01, 1.528962049633e-03, 1.0100e+00, 2.5532e-02,
#  2DIAGNOSTIC,    17, -5.761505365372e-01, 3.194897726644e-04, 1.0361e+00, 2.6116e-02,
#  2DIAGNOSTIC,    18, -5.761749148369e-01, 6.337822560454e-05, 1.0595e+00, 2.3373e-02,
#  2DIAGNOSTIC,    19, -5.760948657990e-01, 4.928037014906e-06, 1.0871e+00, 2.7626e-02,
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -4.969764947891e-01, inf, 1.9048e+00, 8.1766e-01,
#  2DIAGNOSTIC,     2, -4.971752464771e-01, inf, 2.0854e+00, 1.8055e-01,
#  2DIAGNOSTIC,     3, -4.972273707390e-01, inf, 2.2601e+00, 1.7472e-01,
#  2DIAGNOSTIC,     4, -4.972023367882e-01, inf, 2.4344e+00, 1.7436e-01,
#  2DIAGNOSTIC,     5, -4.972149133682e-01, inf, 2.6218e+00, 1.8738e-01,
#  2DIAGNOSTIC,     6, -4.972153007984e-01, inf, 2.8474e+00, 2.2559e-01,
#  2DIAGNOSTIC,     7, -4.971909821033e-01, inf, 3.0408e+00, 1.9334e-01,
#  2DIAGNOSTIC,     8, -4.971960186958e-01, inf, 3.2613e+00, 2.2055e-01,
#  2DIAGNOSTIC,     9, -4.971768558025e-01, inf, 3.4238e+00, 1.6248e-01,
#  2DIAGNOSTIC,    10, -4.971751272678e-01, 1.305840032728e-05, 3.6039e+00, 1.8007e-01,
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -4.162470400333e-01, inf, 4.3968e+00, 7.9299e-01,
#  2DIAGNOSTIC,     2, -4.167902469635e-01, inf, 4.6006e+00, 2.0373e-01,
#  2DIAGNOSTIC,     3, -4.174673855305e-01, inf, 4.7592e+00, 1.5865e-01,
#  2DIAGNOSTIC,     4, -4.184365868568e-01, inf, 4.9202e+00, 1.6096e-01,
#  2DIAGNOSTIC,     5, -4.196120798588e-01, inf, 5.0666e+00, 1.4643e-01,
#  2DIAGNOSTIC,     6, -4.206550121307e-01, inf, 5.2295e+00, 1.6293e-01,
#  2DIAGNOSTIC,     7, -4.285012483597e-01, inf, 5.5853e+00, 3.5577e-01,
#  2DIAGNOSTIC,     8, -4.285416901112e-01, inf, 5.7795e+00, 1.9421e-01,
#  2DIAGNOSTIC,     9, -4.285220205784e-01, inf, 6.0381e+00, 2.5856e-01,
#  2DIAGNOSTIC,    10, -4.285368025303e-01, 2.370960777625e-03, 6.2597e+00, 2.2159e-01,
#  2DIAGNOSTIC,    11, -4.285150170326e-01, 2.076616045088e-03, 6.4452e+00, 1.8558e-01,
#  2DIAGNOSTIC,    12, -4.285233914852e-01, 1.670088036917e-03, 6.6146e+00, 1.6939e-01,
#  2DIAGNOSTIC,    13, -4.285025000572e-01, 1.208864152431e-03, 6.7843e+00, 1.6969e-01,
#  2DIAGNOSTIC,    14, -4.284743964672e-01, 7.549160509370e-04, 6.9341e+00, 1.4980e-01,
#  2DIAGNOSTIC,    15, -4.284415543079e-01, 3.473765682429e-04, 7.1261e+00, 1.9201e-01,
# DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  2DIAGNOSTIC,     1, -3.672383725643e-01, inf, 8.6457e+00, 1.5195e+00,
#   Elapsed time (stage 0): 1.0030e+01
#
#
# Stage 1
#   iterations = 40x20x0
#   convergence threshold = 1.0000e-07
#   convergence window size = 8
#   number of levels = 3
#   using the Mattes MI metric (number of bins = 32, weight = 1.0000e+00, use gradient filter = 0)
#   preprocessing:  histogram matching the images
#   Shrink factors (level 1 out of 3): [4, 4, 4]
#   Shrink factors (level 2 out of 3): [2, 2, 2]
#   Shrink factors (level 3 out of 3): [1, 1, 1]
#   smoothing sigmas per level: [2, 1, 0]
#   Using default NONE metricSamplingStrategy
#
# *** Running SyN registration (varianceForUpdateField = 3.0000e+00, varianceForTotalField = 0.0000e+00) ***
#
# XXDIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  1DIAGNOSTIC,     1, -4.366120994091e-01, inf, 6.9685e-01, 6.9685e-01,
#  1DIAGNOSTIC,     2, -4.463244378567e-01, inf, 8.9520e-01, 1.9834e-01,
#  1DIAGNOSTIC,     3, -4.578560590744e-01, inf, 1.0931e+00, 1.9792e-01,
#  1DIAGNOSTIC,     4, -4.696064591408e-01, inf, 1.3457e+00, 2.5257e-01,
#  1DIAGNOSTIC,     5, -4.799963235855e-01, inf, 1.5472e+00, 2.0155e-01,
#  1DIAGNOSTIC,     6, -4.886278808117e-01, inf, 1.7500e+00, 2.0275e-01,
#  1DIAGNOSTIC,     7, -4.964863061905e-01, inf, 1.9503e+00, 2.0030e-01,
#  1DIAGNOSTIC,     8, -5.035242438316e-01, 1.190471556038e-02, 2.1506e+00, 2.0027e-01,
#  1DIAGNOSTIC,     9, -5.089930295944e-01, 9.627410210669e-03, 2.3717e+00, 2.2118e-01,
#  1DIAGNOSTIC,    10, -5.140405297279e-01, 7.591519970447e-03, 2.5975e+00, 2.2574e-01,
#  1DIAGNOSTIC,    11, -5.181502103806e-01, 5.926465149969e-03, 2.8034e+00, 2.0590e-01,
#  1DIAGNOSTIC,    12, -5.208446979523e-01, 4.595051053911e-03, 3.0189e+00, 2.1552e-01,
#  1DIAGNOSTIC,    13, -5.227913260460e-01, 3.516456810758e-03, 3.2387e+00, 2.1976e-01,
#  1DIAGNOSTIC,    14, -5.240635871887e-01, 2.608177950606e-03, 3.4707e+00, 2.3201e-01,
#  1DIAGNOSTIC,    15, -5.256415605545e-01, 1.902527990751e-03, 3.6819e+00, 2.1120e-01,
#  1DIAGNOSTIC,    16, -5.264828801155e-01, 1.366391894408e-03, 3.8895e+00, 2.0757e-01,
#  1DIAGNOSTIC,    17, -5.272508859634e-01, 9.597775642760e-04, 4.0990e+00, 2.0951e-01,
#  1DIAGNOSTIC,    18, -5.290251374245e-01, 7.279958226718e-04, 4.3088e+00, 2.0983e-01,
#  1DIAGNOSTIC,    19, -5.306622982025e-01, 6.269507575780e-04, 4.5368e+00, 2.2799e-01,
#  1DIAGNOSTIC,    20, -5.316143035889e-01, 5.731494748034e-04, 4.7741e+00, 2.3730e-01,
#  1DIAGNOSTIC,    21, -5.306665897369e-01, 4.760761221405e-04, 5.0049e+00, 2.3085e-01,
#  1DIAGNOSTIC,    22, -5.311849117279e-01, 3.756696241908e-04, 5.2133e+00, 2.0841e-01,
#  1DIAGNOSTIC,    23, -5.315401554108e-01, 2.862314577214e-04, 5.4372e+00, 2.2392e-01,
#  1DIAGNOSTIC,    24, -5.318760871887e-01, 1.974244223675e-04, 5.6504e+00, 2.1313e-01,
#  1DIAGNOSTIC,    25, -5.313614606857e-01, 9.550362301525e-05, 5.8621e+00, 2.1168e-01,
#  1DIAGNOSTIC,    26, -5.316071510315e-01, 4.137517680647e-05, 6.0795e+00, 2.1740e-01,
#  1DIAGNOSTIC,    27, -5.317087173462e-01, 2.811399463098e-05, 6.2870e+00, 2.0753e-01,
#  1DIAGNOSTIC,    28, -5.322452783585e-01, 4.896572136204e-05, 6.5561e+00, 2.6908e-01,
#  1DIAGNOSTIC,    29, -5.326361656189e-01, 4.835886647925e-05, 6.7870e+00, 2.3096e-01,
#  1DIAGNOSTIC,    30, -5.335385799408e-01, 7.327067578444e-05, 7.0063e+00, 2.1924e-01,
#  1DIAGNOSTIC,    31, -5.345818996429e-01, 1.161089239758e-04, 7.2120e+00, 2.0573e-01,
#  1DIAGNOSTIC,    32, -5.342123508453e-01, 1.386867224937e-04, 7.4318e+00, 2.1977e-01,
#  1DIAGNOSTIC,    33, -5.324219465256e-01, 9.255483018933e-05, 7.6549e+00, 2.2312e-01,
#  1DIAGNOSTIC,    34, -5.311771631241e-01, 1.605569195817e-05, 7.8714e+00, 2.1646e-01,
#  1DIAGNOSTIC,    35, -5.301499962807e-01, -7.700920104980e-05, 8.0837e+00, 2.1234e-01,
# XXDIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
#  1DIAGNOSTIC,     1, -4.480897784233e-01, inf, 1.0985e+01, 2.9009e+00,
#  1DIAGNOSTIC,     2, -4.496878981590e-01, inf, 1.2546e+01, 1.5614e+00,
#  1DIAGNOSTIC,     3, -4.512347579002e-01, inf, 1.4254e+01, 1.7079e+00,
#  1DIAGNOSTIC,     4, -4.522813558578e-01, inf, 1.5770e+01, 1.5166e+00,
#  1DIAGNOSTIC,     5, -4.530684351921e-01, inf, 1.7370e+01, 1.5994e+00,
#  1DIAGNOSTIC,     6, -4.536793231964e-01, inf, 1.8934e+01, 1.5640e+00,
#  1DIAGNOSTIC,     7, -4.539214074612e-01, inf, 2.0540e+01, 1.6063e+00,
#  1DIAGNOSTIC,     8, -4.542411863804e-01, 1.092837424949e-03, 2.2177e+01, 1.6370e+00,
#  1DIAGNOSTIC,     9, -4.546167254448e-01, 7.350337691605e-04, 2.5253e+01, 3.0757e+00,
#  1DIAGNOSTIC,    10, -4.549136757851e-01, 4.945517284796e-04, 2.7947e+01, 2.6939e+00,
#  1DIAGNOSTIC,    11, -4.551972150803e-01, 3.587730461732e-04, 2.9459e+01, 1.5128e+00,
#  1DIAGNOSTIC,    12, -4.553490281105e-01, 2.731242857408e-04, 3.0866e+01, 1.4060e+00,
#  1DIAGNOSTIC,    13, -4.553873538971e-01, 2.113223890774e-04, 3.2163e+01, 1.2973e+00,
#  1DIAGNOSTIC,    14, -4.553608298302e-01, 1.611996704014e-04, 3.3738e+01, 1.5755e+00,
#  1DIAGNOSTIC,    15, -4.552766680717e-01, 1.033516018651e-04, 3.5771e+01, 2.0326e+00,
#  1DIAGNOSTIC,    16, -4.552309513092e-01, 5.152097219252e-05, 3.8371e+01, 2.6002e+00,
#  1DIAGNOSTIC,    17, -4.550673365593e-01, 8.382923624595e-06, 4.0101e+01, 1.7300e+00,
#  1DIAGNOSTIC,    18, -4.547738432884e-01, -3.063065742026e-05, 4.1525e+01, 1.4240e+00,
#   Elapsed time (stage 1): 44.64
#
#
# Total elapsed time: 54.68

# %%
print(transformation)
# Out:
# {'warpedmovout': ANTsImage (IAL)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (192, 192, 160)
# 	 Spacing    : (1.25, 1.25, 1.2)
# 	 Origin     : (98.1114, -149.1525, -129.5975)
# 	 Direction  : [ 0.  0. -1.  0.  1.  0.  1.  0.  0.]
# , 'warpedfixout': ANTsImage (IAL)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (189, 233, 197)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (98.0, -98.0, -72.0)
# 	 Direction  : [ 0.  0. -1.  0.  1.  0.  1.  0.  0.]
# , 'fwdtransforms': ['/tmp/tmp4a8bhk531Warp.nii.gz', '/tmp/tmp4a8bhk530GenericAffine.mat'], 'invtransforms': ['/tmp/tmp4a8bhk530GenericAffine.mat', '/tmp/tmp4a8bhk531InverseWarp.nii.gz']}

# %%
registered_img_ants = transformation['warpedmovout']

explore_3D_array_comparison(
    arr_before=raw_img_ants.numpy(), 
    arr_after=registered_img_ants.numpy()
)
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# #### Apply the generated transformations to the mask of template

# %%
brain_mask = ants.apply_transforms(
    fixed=transformation['warpedmovout'],
    moving=mask_template_img_ants,
    transformlist=transformation['fwdtransforms'],
    interpolator='nearestNeighbor',
    verbose=True
)
# Out:
# ['-d', '3', '-i', '0x78aadbb92288', '-o', '0x78ab35743668', '-r', '0x78aadc524268', '-n', 'nearestNeighbor', '-t', '/tmp/tmp4a8bhk531Warp.nii.gz', '-t', '/tmp/tmp4a8bhk530GenericAffine.mat']
# Using double precision for computations.
# Input scalar image: 0x78aadbb92288
# Could not create ImageIO for the input file, assuming dimension = 3 and scalar pixel type
# Reference image: 0x78aadc524268
# =============================================================================
# The composite transform comprises the following transforms (in order):
#   1. /tmp/tmp4a8bhk530GenericAffine.mat (type = AffineTransform)
#   2. /tmp/tmp4a8bhk531Warp.nii.gz (type = DisplacementFieldTransform)
# =============================================================================
# Default pixel value: 0
# Interpolation type: NearestNeighborInterpolateImageFunction
# Output warped image: 0x78ab35743668

# %%
explore_3D_array(brain_mask.numpy())
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %%
explore_3D_array_with_mask_contour(raw_img_ants.numpy(), brain_mask.numpy())
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %%
brain_mask_dilated = ants.morphology(brain_mask, radius=4, operation='dilate', mtype='binary')

explore_3D_array_with_mask_contour(raw_img_ants.numpy(), brain_mask_dilated.numpy())
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# #### Save brain mask

# %%
out_folder =  os.path.join(BASE_DIR, 'assets', 'preprocessed')
out_folder = os.path.join(out_folder, raw_example.split('.')[0]) # create folder with name of the raw file
os.makedirs(out_folder, exist_ok=True) # create folder if not exists

out_filename = add_suffix_to_filename(raw_example, suffix='brainMaskByTemplate')
out_path = os.path.join(out_folder, out_filename)

print(raw_img_path[len(BASE_DIR):])
print(out_path[len(BASE_DIR):])
# Out:
# /assets/raw_examples/fsl-open-dev_sub-001_T1w.nii.gz
# /assets/preprocessed/fsl-open-dev_sub-001_T1w/fsl-open-dev_sub-001_T1w_brainMaskByTemplate.nii.gz

# %%
brain_mask_dilated.to_file(out_path)

# %% [markdown]
# #### Generate brain masked

# %%
masked = ants.mask_image(raw_img_ants, brain_mask_dilated)

explore_3D_array(masked.numpy())
# Out:
# interactive(children=(IntSlider(value=95, description='SLICE', max=191), Output()), _dom_classes=('widget-inte…

# %%
out_filename = add_suffix_to_filename(raw_example, suffix='brainMaskedByTemplate')
out_path = os.path.join(out_folder, out_filename)

print(raw_img_path[len(BASE_DIR):])
print(out_path[len(BASE_DIR):])
# Out:
# /assets/raw_examples/fsl-open-dev_sub-001_T1w.nii.gz
# /assets/preprocessed/fsl-open-dev_sub-001_T1w/fsl-open-dev_sub-001_T1w_brainMaskedByTemplate.nii.gz

# %%
masked.to_file(out_path)
